# %%
import torch
from ear_dataset import EarDataset, EarTriplet

train_dataset = torch.load(f"data/train_dataset_1.pt")
# Out:
# 122749 123286

# %%
print(len(train_dataset.anchor_data), len(train_dataset.positive_data), len(train_dataset.negative_data))

train_dataset.anchor_data[0].shape
# Out:
# 122749 123286 122749
# torch.Size([3, 64, 64])

# %%
import matplotlib.pyplot as plt

plt.imshow(train_dataset.anchor_data[0].permute(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
